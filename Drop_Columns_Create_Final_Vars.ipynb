# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

#Only import this once
#df = pd.read_csv('pdb2019bgv3_us.csv', encoding='ISO-8859-1')

# %%
#Creates new_column_df which is an dataframe of column names
#with index

column_list = []
index_list = []
counter = 0
for i in df.columns:
    counter += 1
    column_list.append(i), index_list.append(counter)

new_column_df = pd.DataFrame({'Index': index_list,
     'Column': column_list})

# %%
#Df2 is a data frame containing true variable types
#Determined from reading the metadata file
df2 = pd.read_excel('Variable_types.xlsx')
df2.replace(np.NaN, 0, inplace=True)
df2 = df2.astype(dtype= int)

# %%
df2.head()
# Out:
#    Index  Categorical  Numeric  Integer
# 0      1            1        0        0
# 1      2            1        0        0
# 2      3            1        0        0
# 3      4            1        0        0
# 4      5            1        0        0

# %%
#Merge df2 and new_column_df
df_columns_true_type = pd.merge(new_column_df, df2, how= 'left', left_on='Index', right_on='Index')
df_columns_true_type.head(2)
df_columns_true_type
# Out:
#    Index Column  Categorical  Numeric  Integer
# 0      1  GIDBG            1        0        0
# 1      2  State            1        0        0

# %%
#df_columns_true_type.to_csv('Column_Data_Types')

# %%
#Create list of MOE variable to be dropped from df_columns_true_type
MOE_Variable_List = []
MOE_Index = []
MOE_Is_True = []
strings = list(df.columns)
True_MOE = 1
counter2 = 0
for string in strings:
    if ("MOE" in string) == True:
        MOE_Variable_List.append(string)
        MOE_Index.append(counter2)
        MOE_Is_True.append(True_MOE)
        counter2 += 1
    else:
        pass

MOE_Variable_Df = pd.DataFrame({'Index': MOE_Index,
     'MOE_Variables': MOE_Variable_List, 'MOE_Is_True': MOE_Is_True})

# %%
MOE_Variable_Df.head(2)
# Out:
#    Index                MOE_Variables  MOE_Is_True
# 0      0  Tot_Population_ACSMOE_13_17            1
# 1      1           Males_ACSMOE_13_17            1

# %%
#Merge list of columns and MOE_is_True
df_columns_true_type = pd.merge(df_columns_true_type, MOE_Variable_Df.iloc[:,1:3], how= 'left', left_on='Column', right_on='MOE_Variables',
                            )
df_columns_true_type = df_columns_true_type.replace(np.NaN, 0)

# %%
#Set up for dropping MOE variables
df_columns_true_type.head()
# Out:
#    Index       Column  Categorical  Numeric  Integer MOE_Variables  MOE_Is_True
# 0      1        GIDBG            1        0        0             0          0.0
# 1      2        State            1        0        0             0          0.0
# 2      3   State_name            1        0        0             0          0.0
# 3      4       County            1        0        0             0          0.0
# 4      5  County_name            1        0        0             0          0.0

# %%
#Drops Margin of Error Variables
df_columns_true_type_dropped = df_columns_true_type[df_columns_true_type.MOE_Is_True != 1.0]

# %%
df_columns_true_type_dropped
# Out:
#      Index                            Column  Categorical  Numeric  Integer MOE_Variables  MOE_Is_True
# 0        1                             GIDBG            1        0        0             0          0.0
# 1        2                             State            1        0        0             0          0.0
# 2        3                        State_name            1        0        0             0          0.0
# 3        4                            County            1        0        0             0          0.0
# 4        5                       County_name            1        0        0             0          0.0
# 5        6                             Tract            1        0        0             0          0.0
# 6        7                       Block_group            1        0        0             0          0.0
# 7        8                              Flag            1        0        0             0          0.0
# ...

# %%
#This is the number of variables dropped
len(df_columns_true_type) - len(df_columns_true_type_dropped)
# Out:
# 121

# %%
##Check original data for missing values
percent_missing_vals = df.isna().mean().round(4)
###We should drop about 5 columns
percent_missing_vals.sort_values(ascending=False).head(10)
# Out:
# Flag                                0.9973
# pct_BILQ_Mailout_count_CEN_2010     0.8913
# BILQ_Mailout_count_CEN_2010         0.8913
# BILQ_Frms_CEN_2010                  0.8913
# TEA_Update_Leave_CEN_2010           0.8907
# pct_TEA_Update_Leave_CEN_2010       0.8907
# avg_Agg_House_Value_ACSMOE_13_17    0.1261
# Aggr_House_Value_ACSMOE_13_17       0.1261
# avg_Agg_House_Value_ACS_13_17       0.1261
# Aggr_House_Value_ACS_13_17          0.1261
# dtype: float64

# %%
#Drop Missing Value Columns
drop_list_percent_missing_vals = ['Flag', 'pct_BILQ_Mailout_count_CEN_2010', 'BILQ_Mailout_count_CEN_2010', 'BILQ_Frms_CEN_2010', 'pct_TEA_Update_Leave_CEN_2010']
dropping_list = df_columns_true_type_dropped.Column.isin(drop_list_percent_missing_vals)
DF_Final_Vars = df_columns_true_type_dropped.Column[~dropping_list]

# %%
#DF_Final_Vars.to_csv('DF_Final_Vars')

# %%
isolated_categorical_variables = df_columns_true_type[df_columns_true_type_dropped['Categorical'] == 1]
isolated_integer_variables = df_columns_true_type[df_columns_true_type_dropped['Integer'] == 1]
isolated_numeric_variables = df_columns_true_type[df_columns_true_type_dropped['Numeric'] == 1]
# Out:
# /Users/Mango/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-40-38288bb14657> in <module>()
# ----> 1 isolated_categorical_variables = df_columns_true_type[df_columns_true_type_dropped['Categorical'] == 1]
#       2 isolated_integer_variables = df_columns_true_type[df_columns_true_type_dropped['Integer'] == 1]
#       3 isolated_numeric_variables = df_columns_true_type[df_columns_true_type_dropped['Numeric'] == 1]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# ...

# %%
df

# %%
#Determine columns to be dropped due to missing values
percent_missing_vals.sort_values(ascending=False).index
drop_list_percent_missing_vals = ['Flag', 'pct_BILQ_Mailout_count_CEN_2010', 'BILQ_Mailout_count_CEN_2010', 'BILQ_Frms_CEN_2010', 'pct_TEA_Update_Leave_CEN_2010']

# %%
df_columns_true_type_dropped.head(3)

# %%
dropping_list = df_columns_true_type_dropped.Column.isin(drop_list_percent_missing_vals)

# %%
DF_All_Droped_Vars = df_columns_true_type_dropped[~dropping_list]

# %%
len(DF_All_Droped_Vars)

# %%
Final_Variables = DF_All_Droped_Vars.iloc[:,0:2]

# %%
Final_Variables = df = Final_Variables.reset_index(drop=True)

# %%
Final_Variables

# %%
df2 =  pd.read_excel('Variable_types.xlsx')

df2.replace(np.NaN, 0, inplace=True)
df2.astype(dtype= int, inplace=True)
