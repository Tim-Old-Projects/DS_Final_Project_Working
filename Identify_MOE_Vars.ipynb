# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

#Only import this once
df = pd.read_csv('pdb2019bgv3_us.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#          GIDBG  State State_name  County     County_name  Tract  Block_group  Flag  LAND_AREA  AIAN_LAND  URBANIZED_AREA_POP_CEN_2010  URBAN_CLUSTER_POP_CEN_2010  RURAL_POP_CEN_2010  Tot_Population_CEN_2010  Tot_Population_ACS_13_17  Tot_Population_ACSMOE_13_17  Males_CEN_2010  Males_ACS_13_17  Males_ACSMOE_13_17  Females_CEN_2010  Females_ACS_13_17  Females_ACSMOE_13_17  Median_Age_ACS_13_17  Median_Age_ACSMOE_13_17  Pop_under_5_CEN_2010  Pop_under_5_ACS_13_17  Pop_under_5_ACSMOE_13_17  Pop_5_17_CEN_2010  Pop_5_17_ACS_13_17  Pop_5_17_ACSMOE_13_17  Pop_18_24_CEN_2010  Pop_18_24_ACS_13_17  Pop_18_24_ACSMOE_13_17  Pop_25_44_CEN_2010  Pop_25_44_ACS_13_17  Pop_25_44_ACSMOE_13_17  Pop_45_64_CEN_2010  Pop_45_64_ACS_13_17  Pop_45_64_ACSMOE_13_17  Pop_65plus_CEN_2010  Pop_65plus_ACS_13_17  Pop_65plus_ACSMOE_13_17  Tot_GQ_CEN_2010  Inst_GQ_CEN_2010  Non_Inst_GQ_CEN_2010  Hispanic_CEN_2010  Hispanic_ACS_13_17  Hispanic_ACSMOE_13_17  NH_White_alone_CEN_2010  NH_White_alone_ACS_13_17  \
# ...

# %%
column_list = []
index_list = []
counter = 0
for i in df.columns:
    counter += 1
    column_list.append(i), index_list.append(counter)
#print(column_list)
print(column_list)
print(index_list)
# Out:
# ['GIDBG', 'State', 'State_name', 'County', 'County_name', 'Tract', 'Block_group', 'Flag', 'LAND_AREA', 'AIAN_LAND', 'URBANIZED_AREA_POP_CEN_2010', 'URBAN_CLUSTER_POP_CEN_2010', 'RURAL_POP_CEN_2010', 'Tot_Population_CEN_2010', 'Tot_Population_ACS_13_17', 'Tot_Population_ACSMOE_13_17', 'Males_CEN_2010', 'Males_ACS_13_17', 'Males_ACSMOE_13_17', 'Females_CEN_2010', 'Females_ACS_13_17', 'Females_ACSMOE_13_17', 'Median_Age_ACS_13_17', 'Median_Age_ACSMOE_13_17', 'Pop_under_5_CEN_2010', 'Pop_under_5_ACS_13_17', 'Pop_under_5_ACSMOE_13_17', 'Pop_5_17_CEN_2010', 'Pop_5_17_ACS_13_17', 'Pop_5_17_ACSMOE_13_17', 'Pop_18_24_CEN_2010', 'Pop_18_24_ACS_13_17', 'Pop_18_24_ACSMOE_13_17', 'Pop_25_44_CEN_2010', 'Pop_25_44_ACS_13_17', 'Pop_25_44_ACSMOE_13_17', 'Pop_45_64_CEN_2010', 'Pop_45_64_ACS_13_17', 'Pop_45_64_ACSMOE_13_17', 'Pop_65plus_CEN_2010', 'Pop_65plus_ACS_13_17', 'Pop_65plus_ACSMOE_13_17', 'Tot_GQ_CEN_2010', 'Inst_GQ_CEN_2010', 'Non_Inst_GQ_CEN_2010', 'Hispanic_CEN_2010', 'Hispanic_ACS_13_17', 
# ...

# %%
new_column_df = pd.DataFrame({'Index': index_list,
     'Column': column_list})
new_column_df
# Out:
#      Index                            Column
# 0        1                             GIDBG
# 1        2                             State
# 2        3                        State_name
# 3        4                            County
# 4        5                       County_name
# 5        6                             Tract
# 6        7                       Block_group
# 7        8                              Flag
# 8        9                         LAND_AREA
# 9       10                         AIAN_LAND
# 10      11       URBANIZED_AREA_POP_CEN_2010
# 11      12        URBAN_CLUSTER_POP_CEN_2010
# 12      13                RURAL_POP_CEN_2010
# 13      14           Tot_Population_CEN_2010
# 14      15          Tot_Population_ACS_13_17
# 15      16       Tot_Population_ACSMOE_13_17
# 16      17                    Males_CEN_2010
# 17      18                   Males_ACS_13_17
# 18      19                Males_ACSMOE_13_17
# 19      20                  Females_CEN_2010
# ...

# %%
"MOE" in "Tot_Population_ACSMOE_13_17"
# Out:
# True

# %%
type(new_column_df['Column'][0])
# Out:
# str

# %%
strings = list(new_column_df['Column'])
type(strings[0])
"MOE" in strings[0]
# Out:
# False

# %%
MOE_Variable_List = []
MOE_Index = []
counter2 = 0
for string in strings:
    if ("MOE" in string) == True:
        MOE_Variable_List.append(string), MOE_Index.append(counter2)
        counter2 += 1
    else:
        pass
MOE_Variable_List
MOE_Variable_Df = pd.DataFrame({'Index': MOE_Index,
     'MOE_Variables': MOE_Variable_List})

# %%
MOE_Variable_Df
# Out:
#      Index                     MOE_Variables
# 0        0       Tot_Population_ACSMOE_13_17
# 1        1                Males_ACSMOE_13_17
# 2        2              Females_ACSMOE_13_17
# 3        3           Median_Age_ACSMOE_13_17
# 4        4          Pop_under_5_ACSMOE_13_17
# 5        5             Pop_5_17_ACSMOE_13_17
# 6        6            Pop_18_24_ACSMOE_13_17
# 7        7            Pop_25_44_ACSMOE_13_17
# 8        8            Pop_45_64_ACSMOE_13_17
# 9        9           Pop_65plus_ACSMOE_13_17
# 10      10             Hispanic_ACSMOE_13_17
# 11      11       NH_White_alone_ACSMOE_13_17
# 12      12         NH_Blk_alone_ACSMOE_13_17
# 13      13        NH_AIAN_alone_ACSMOE_13_17
# 14      14       NH_Asian_alone_ACSMOE_13_17
# 15      15       NH_NHOPI_alone_ACSMOE_13_17
# 16      16         NH_SOR_alone_ACSMOE_13_17
# 17      17        Pop_5yrs_Over_ACSMOE_13_17
# 18      18            Othr_Lang_ACSMOE_13_17
# 19      19       Pop_25yrs_Over_ACSMOE_13_17
# ...
